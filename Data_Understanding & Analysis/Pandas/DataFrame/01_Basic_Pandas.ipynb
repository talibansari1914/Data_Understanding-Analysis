# %% [markdown]
# ### PANDAS LIBRARY ###

# %% [markdown]
# # IF NOT WITH THE ANANCONDA THEN WE SHOULD INSTALL FROM ANACONDA TERMINAL-----> pip install pandas

# %% [markdown]
# # PANDAS USE :
# 1.
# # PANDAS DATA STRUCTURE OR OBJECT CREATION :
# 1..DataFrame(# dict_name)----> used for 2D (rows & columns creation)----->it is a class
#     #CAN BE WRITTEN AS ALSO WHEN WE PROVIDE THE INDEX
#     .DataFrame(dict_name,index=index_name)
#
# 2..Series(#dict_name)--------> used for 1D (only rows creation)-------> it is a class
#     #CAN BE WRITTEN AS WHEN WE PROVIDE THE INDEX
#     .Series(dict_name,index=index_name)

# %% [markdown]
# ## 05-08-2025 practice on
# 1.pandas import
# 2.pandas as alias name use
# 3.DataFrame() use
#   3.0 empty DataFrame call
#   3.1 head()
#   3.2 info()
#   3.3 tail()
#   3.4 describe()
#   3.5 loc()
#   3.6 iloc()
#
# 4.Series()use
#   4.0 empty Series call
#   4.1 head()
#   4.2 info()
#   4.3 tail()
#   4.4 describe()
#   4.5 loc()
#   4.6 iloc()

# %%
import pandas 
print(("hello"))
# Out:
# hello

# %%
import pandas as pd
st="hello world"
print(st)
# Out:
# hello world

# %%
import pandas as pd
st1=pd.DataFrame()
print(st1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
st2=pd.DataFrame()
print(st2.head(1))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
st3=pd.DataFrame()
print(st3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame
# None

# %%
import pandas as pd
st4=pd.DataFrame()
print(st4.tail(2))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import pandas as pd
st5=pd.DataFrame()
print(st5.describe())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
#       2 st5=pd.DataFrame()
# ----> 3 print(st5.describe())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# ...

# %%
import pandas as pd
dict_1={
    "name":"talib ansari",
    "phone":"redmi",
    "price":10000,
    "location":"mauganj"
}
d=pd.DataFrame(dict_1)
print(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 8
#       1 import pandas as pd
#       2 dict_1={
#       3     "name":"talib ansari",
#       4     "phone":"redmi",
#       5     "price":10000,
#       6     "location":"mauganj"
#       7 }
# ----> 8 d=pd.DataFrame(dict_1)
#       9 print(d)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# ...

# %%
import pandas as pd
dict_1={
    "name":"talib ansari",
    "phone":"redmi",
    "price":10000,
    "location":"mauganj"
}
d=pd.Series(dict_1)
print(d)
# Out:
# name        talib ansari
# phone              redmi
# price              10000
# location         mauganj
# dtype: object

# %%
import pandas as pd
dict_1={
    "name":"talib ansari",
    "phone":"redmi",
    "price":10000,
    "location":"mauganj"
}
idx=[0]
d=pd.DataFrame(dict_1,index=idx)
print(d)
# Out:
#            name  phone  price location
# 0  talib ansari  redmi  10000  mauganj

# %%
import pandas as pd
dict_1={
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
#idx=[0]
d=pd.DataFrame(dict_1)
print(d)
# Out:
#            name     phone  price  location
# 0  talib ansari     redmi  10000   mauganj
# 1         vipul  motorola  20000      rewa
# 2          anil   redmi-8  10000  devtalab
# 3           raj      oppo  15000    bhopal

# %%
import pandas as pd
dict_1={
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=[0]
d=pd.DataFrame(dict_1,index=idx)
print(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 9
#       2 dict_1={
#       3     "name":["talib ansari","vipul","anil","raj"],
#       4     "phone":["redmi","motorola","redmi-8","oppo"],
#       5     "price":[10000,20000,10000,15000],
#       6     "location":["mauganj","rewa","devtalab","bhopal"]
#       7 }
#       8 idx=[0]
# ----> 9 d=pd.DataFrame(dict_1,index=idx)
#      10 print(d)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# ...

# %%
import pandas as pd
dict_1={
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=[0,1,2,3,4]
d=pd.DataFrame(dict_1,index=idx)
print(d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 9
#       2 dict_1={
#       3     "name":["talib ansari","vipul","anil","raj"],
#       4     "phone":["redmi","motorola","redmi-8","oppo"],
#       5     "price":[10000,20000,10000,15000],
#       6     "location":["mauganj","rewa","devtalab","bhopal"]
#       7 }
#       8 idx=[0,1,2,3,4]
# ----> 9 d=pd.DataFrame(dict_1,index=idx)
#      10 print(d)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# ...

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
print(d)
# Out:
#                  name     phone  price  location
# buyer_1  talib ansari     redmi  10000   mauganj
# buyer_2         vipul  motorola  20000      rewa
# buyer_3          anil   redmi-8  10000  devtalab
# buyer_4           raj      oppo  15000    bhopal

# %%
import pandas as pd
dict_1={
    "sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1)
print(d)
# Out:
#      sr-no          name     phone  price  location
# 0  buyer_1  talib ansari     redmi  10000   mauganj
# 1  buyer_2         vipul  motorola  20000      rewa
# 2  buyer_3          anil   redmi-8  10000  devtalab
# 3  buyer_4           raj      oppo  15000    bhopal

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d.head(2)
# Out:
#                  name     phone  price location
# buyer_1  talib ansari     redmi  10000  mauganj
# buyer_2         vipul  motorola  20000     rewa

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d.tail(2)
# Out:
#          name    phone  price  location
# buyer_3  anil  redmi-8  10000  devtalab
# buyer_4   raj     oppo  15000    bhopal

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d
# Out:
#                  name     phone  price  location
# buyer_1  talib ansari     redmi  10000   mauganj
# buyer_2         vipul  motorola  20000      rewa
# buyer_3          anil   redmi-8  10000  devtalab
# buyer_4           raj      oppo  15000    bhopal

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, buyer_1 to buyer_4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      4 non-null      object
#  1   phone     4 non-null      object
#  2   price     4 non-null      int64
#  3   location  4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 160.0+ bytes

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d.describe()
# Out:
#               price
# count      4.000000
# mean   13750.000000
# std     4787.135539
# min    10000.000000
# 25%    10000.000000
# 50%    12500.000000
# 75%    16250.000000
# max    20000.000000

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d["name"]
# Out:
# buyer_1    talib ansari
# buyer_2           vipul
# buyer_3            anil
# buyer_4             raj
# Name: name, dtype: object

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 11
#       9 idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
# ...

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d.loc["buyer_1"]
# Out:
# name        talib ansari
# phone              redmi
# price              10000
# location         mauganj
# Name: buyer_1, dtype: object

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
#idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,)
d.loc[1]
# Out:
# name           vipul
# phone       motorola
# price          20000
# location        rewa
# Name: 1, dtype: object

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
#idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,)
d.iloc[3]
# Out:
# name           raj
# phone         oppo
# price        15000
# location    bhopal
# Name: 3, dtype: object

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
#idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,)
d.iloc[:]
# Out:
#            name     phone  price  location
# 0  talib ansari     redmi  10000   mauganj
# 1         vipul  motorola  20000      rewa
# 2          anil   redmi-8  10000  devtalab
# 3           raj      oppo  15000    bhopal

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
#idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,)
d.iloc[:2]
# Out:
#            name     phone  price location
# 0  talib ansari     redmi  10000  mauganj
# 1         vipul  motorola  20000     rewa

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
print(d.iloc[1,2])
# Out:
# 20000

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
print(d.iloc[:,0:1])
# Out:
#                  name
# buyer_1  talib ansari
# buyer_2         vipul
# buyer_3          anil
# buyer_4           raj

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
print(d.iloc[[1,2],[2,1]])
# Out:
#          price     phone
# buyer_2  20000  motorola
# buyer_3  10000   redmi-8

# %%
import pandas as pd
dict_1={
    #"sr-no":idx,
    "name":["talib ansari","vipul","anil","raj"],
    "phone":["redmi","motorola","redmi-8","oppo"],
    "price":[10000,20000,10000,15000],
    "location":["mauganj","rewa","devtalab","bhopal"]
}
idx=["buyer_1","buyer_2","buyer_3","buyer_4"]
d=pd.DataFrame(dict_1,index=idx)
d
# Out:
#                  name     phone  price  location
# buyer_1  talib ansari     redmi  10000   mauganj
# buyer_2         vipul  motorola  20000      rewa
# buyer_3          anil   redmi-8  10000  devtalab
# buyer_4           raj      oppo  15000    bhopal

# %% [markdown]
# # Series

# %%
import pandas as pd
price=[10000,20000,10000,15000]
sr_d=pd.Series(price)
sr_d
# Out:
# 0    10000
# 1    20000
# 2    10000
# 3    15000
# dtype: int64

# %%
import pandas as pd
new_price=[]
sr_n=pd.Series(new_price)
sr_n
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
new_price=[]
sr_n=pd.Series(new_price)
sr_n.head()
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
new_price=[]
sr_n=pd.Series(new_price)
sr_n.tail()
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
new_price=[]
sr_n=pd.Series(new_price)
sr_n.describe()
# Out:
# count       0
# unique      0
# top       NaN
# freq      NaN
# dtype: object

# %%
import pandas as pd
new_price=[]
sr_n=pd.Series(new_price)
sr_n.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 0 entries
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 0 non-null      object
# dtypes: object(1)
# memory usage: 132.0+ bytes

# %%
import pandas as pd
new_price=[]
sr_n=pd.Series(new_price)
sr_n.loc[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 0 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 4
#       2 new_price=[]
#       3 sr_n=pd.Series(new_price)
# ----> 4 sr_n.loc[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
import pandas as pd
new_price=[]
sr_n=pd.Series(new_price)
sr_n.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[71], line 4
#       2 new_price=[]
#       3 sr_n=pd.Series(new_price)
# ----> 4 sr_n.iloc[0]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list=pd.Series(list_speed)
sr_list
# Out:
# 0    [20, 30]
# 1    [40, 50]
# 2    [60, 70]
# dtype: object

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list,*sr_list1=pd.Series(list_speed)
sr_list,sr_list1
# Out:
# ([20, 30], [[40, 50], [60, 70]])

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list,*sr_list1=pd.Series(list_speed)
sr_list,sr_list1.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[79], line 4
#       2 list_speed=[[20,30],[40,50],[60,70]]
#       3 sr_list,*sr_list1=pd.Series(list_speed)
# ----> 4 sr_list,sr_list1.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list1=pd.Series(list_speed)
print(*sr_list1)
# Out:
# [20, 30] [40, 50] [60, 70]

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
idx=[0,1,2]
sr_list1=pd.Series(list_speed,index=idx)
print(*sr_list1)
# Out:
# [20, 30] [40, 50] [60, 70]

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list1=pd.Series(list_speed)
print(*sr_list1.head(1))
# Out:
# [20, 30]

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list1=pd.Series(list_speed)
print(*sr_list1.tail(1))
# Out:
# [60, 70]

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list1=pd.Series(list_speed)
print(*sr_list1.info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 3 entries, 0 to 2
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 4
#       2 list_speed=[[20,30],[40,50],[60,70]]
#       3 sr_list1=pd.Series(list_speed)
# ----> 4 print(*sr_list1.info())
#
# TypeError: print() argument after * must be an iterable, not NoneType

# %%
import pandas as pd
list_speed=[[20,30],[40,50],[60,70]]
sr_list1=pd.Series(list_speed)
print(*sr_list1.describe())
# Out:
# 3 3 [20, 30] 1

# %% [markdown]
# # DataFrame

# %%
import pandas as pd
dict_1={
    'course':["Data Science","Ai","Full-stack",".net"],
    'duration':["6 months","3-months","8-months","5-months"],
    'fee':[27000,30000,40000,25000],
    'teacher':['Jayant Kumar','manyank kumar','omkar','hariom']
}
d2=pd.DataFrame(dict_1)
d2
# Out:
#          course  duration    fee        teacher
# 0  Data Science  6 months  27000   Jayant Kumar
# 1            Ai  3-months  30000  manyank kumar
# 2    Full-stack  8-months  40000          omkar
# 3          .net  5-months  25000         hariom

# %%
import pandas as pd
dict_1={
    'course':["Data Science","Ai","Full-stack","Java.net"],
    'duration':["6 months","3-months","8-months","5-months"],
    'fee':[27000,30000,40000,25000],
    'teacher':['Jayant Kumar','manyank kumar','omkar','hariom']
}
idx=["batch-01","batch-02","batch-03","batch-04"]
d2=pd.DataFrame(dict_1,index=idx)
d2
# Out:
#                 course  duration    fee        teacher
# batch-01  Data Science  6 months  27000   Jayant Kumar
# batch-02            Ai  3-months  30000  manyank kumar
# batch-03    Full-stack  8-months  40000          omkar
# batch-04      Java.net  5-months  25000         hariom

# %%
import pandas as pd
dict_1={
    'course':["Data Science","Ai","Full-stack",".net"],
    'duration':["6 months","3-months","8-months","5-months"],
    'fee':[27000,30000,40000,25000],
    'teacher':['Jayant Kumar','manyank kumar','omkar','hariom']
}
d2=pd.DataFrame(dict_1)
d2.head(2)
# Out:
#          course  duration    fee        teacher
# 0  Data Science  6 months  27000   Jayant Kumar
# 1            Ai  3-months  30000  manyank kumar

# %%
import pandas as pd
dict_1={
    'course':["Data Science","Ai","Full-stack",".net"],
    'duration':["6 months","3-months","8-months","5-months"],
    'fee':[27000,30000,40000,25000],
    'teacher':['Jayant Kumar','manyank kumar','omkar','hariom']
}
d2=pd.DataFrame(dict_1)
d2.tail(3)
# Out:
#        course  duration    fee        teacher
# 1          Ai  3-months  30000  manyank kumar
# 2  Full-stack  8-months  40000          omkar
# 3        .net  5-months  25000         hariom

# %%
import pandas as pd
dict_1={
    'course':["Data Science","Ai","Full-stack",".net"],
    'duration':["6 months","3-months","8-months","5-months"],
    'fee':[27000,30000,40000,25000],
    'teacher':['Jayant Kumar','manyank kumar','omkar','hariom']
}
d2=pd.DataFrame(dict_1)
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   course    4 non-null      object
#  1   duration  4 non-null      object
#  2   fee       4 non-null      int64
#  3   teacher   4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes

# %%
import pandas as pd
dict_1={
    'course':["Data Science","Ai","Full-stack",".net"],
    'duration':["6 months","3-months","8-months","5-months"],
    'fee':[27000,30000,40000,25000],
    'teacher':['Jayant Kumar','manyank kumar','omkar','hariom']
}
d2=pd.DataFrame(dict_1)
d2.describe()
# Out:
#                 fee
# count      4.000000
# mean   30500.000000
# std     6658.328118
# min    25000.000000
# 25%    26500.000000
# 50%    28500.000000
# 75%    32500.000000
# max    40000.000000

# %%
import pandas as pd
dict_1={
    'course':["Data Science","Ai","Full-stack","Java.net"],
    'duration':[6 ,3,8,5],
    'fee':[27000,30000,40000,25000],
    'teacher':['Jayant Kumar','manyank kumar','omkar','hariom']
}
d2=pd.DataFrame(dict_1)
d2.describe()
# Out:
#        duration           fee
# count  4.000000      4.000000
# mean   5.500000  30500.000000
# std    2.081666   6658.328118
# min    3.000000  25000.000000
# 25%    4.500000  26500.000000
# 50%    5.500000  28500.000000
# 75%    6.500000  32500.000000
# max    8.000000  40000.000000

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost
# Out:
#    grains   kg_s  cost  selling_price     msp  communication_charge
# 0    rice  10_kg   200            250   20_rs                    20
# 1   wheat  15_kg   150            200   30_rs                    15
# 2     dal   7_kg   300            295   60_rs                    30
# 3   grams   9_kg   350            460  100_rs                    10
# 4    corn   5_kg   500            300  150_rs                     8
# 5  potato  20_kg   100            390   20_rs                    11

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
idx=["Anaj_1","Anaj_2","Anaj_3","Anaj_4","Anaj_5","Anaj_6"]
farmer_cost=pd.DataFrame(farmer,index=idx)
farmer_cost
# Out:
#         grains   kg_s  cost  selling_price     msp  communication_charge
# Anaj_1    rice  10_kg   200            250   20_rs                    20
# Anaj_2   wheat  15_kg   150            200   30_rs                    15
# Anaj_3     dal   7_kg   300            295   60_rs                    30
# Anaj_4   grams   9_kg   350            460  100_rs                    10
# Anaj_5    corn   5_kg   500            300  150_rs                     8
# Anaj_6  potato  20_kg   100            390   20_rs                    11

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost.describe()
# Out:
#              cost  selling_price  communication_charge
# count    6.000000       6.000000              6.000000
# mean   266.666667     315.833333             15.666667
# std    147.196014      94.573604              8.213810
# min    100.000000     200.000000              8.000000
# 25%    162.500000     261.250000             10.250000
# 50%    250.000000     297.500000             13.000000
# 75%    337.500000     367.500000             18.750000
# max    500.000000     460.000000             30.000000

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost.head(2).describe()
# Out:
#              cost  selling_price  communication_charge
# count    2.000000       2.000000              2.000000
# mean   175.000000     225.000000             17.500000
# std     35.355339      35.355339              3.535534
# min    150.000000     200.000000             15.000000
# 25%    162.500000     212.500000             16.250000
# 50%    175.000000     225.000000             17.500000
# 75%    187.500000     237.500000             18.750000
# max    200.000000     250.000000             20.000000

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost.tail(3).describe()
# Out:
#              cost  selling_price  communication_charge
# count    3.000000       3.000000              3.000000
# mean   316.666667     383.333333              9.666667
# std    202.072594      80.208063              1.527525
# min    100.000000     300.000000              8.000000
# 25%    225.000000     345.000000              9.000000
# 50%    350.000000     390.000000             10.000000
# 75%    425.000000     425.000000             10.500000
# max    500.000000     460.000000             11.000000

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   grains                6 non-null      object
#  1   kg_s                  6 non-null      object
#  2   cost                  6 non-null      int64
#  3   selling_price         6 non-null      int64
#  4   msp                   6 non-null      object
#  5   communication_charge  6 non-null      int64
# dtypes: int64(3), object(3)
# memory usage: 420.0+ bytes

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost.loc[0]
# Out:
# grains                   rice
# kg_s                    10_kg
# cost                      200
# selling_price             250
# msp                     20_rs
# communication_charge       20
# Name: 0, dtype: object

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost.loc[1:]
# Out:
#    grains   kg_s  cost  selling_price     msp  communication_charge
# 1   wheat  15_kg   150            200   30_rs                    15
# 2     dal   7_kg   300            295   60_rs                    30
# 3   grams   9_kg   350            460  100_rs                    10
# 4    corn   5_kg   500            300  150_rs                     8
# 5  potato  20_kg   100            390   20_rs                    11

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
farmer_cost.loc[2]
# Out:
# grains                    dal
# kg_s                     7_kg
# cost                      300
# selling_price             295
# msp                     60_rs
# communication_charge       30
# Name: 2, dtype: object

# %%
import pandas as pd
farmer={
    "grains":["rice","wheat","dal","grams","corn","potato"],
    "kg_s":["10_kg","15_kg","7_kg","9_kg","5_kg","20_kg"],
    "cost":[200,150,300,350,500,100],
    "selling_price":[250,200,295,460,300,390],
    "msp":["20_rs","30_rs","60_rs","100_rs","150_rs","20_rs"],
    "communication_charge":[20,15,30,10,8,11]
}
farmer_cost=pd.DataFrame(farmer)
print(farmer_cost.iloc[1,2])
# Out:
# 150

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
shop=pd.DataFrame(my_shop)
shop
# Out:
#          name relation           shop   rent
# 0  jiyaul Hak    uncle  prince tailor  10000
# 1       sanam     bhai  prince tailor  10000
# 2     subrati     bhai  prince tailor  10000

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
idx=["tailor_1","tailor_2","tailor_3"]
shop=pd.DataFrame(my_shop,index=idx)
shop
# Out:
#                 name relation           shop   rent
# tailor_1  jiyaul Hak    uncle  prince tailor  10000
# tailor_2       sanam     bhai  prince tailor  10000
# tailor_3     subrati     bhai  prince tailor  10000

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
idx=["tailor_1","tailor_2","tailor_3"]
shop=pd.DataFrame(my_shop,index=idx)
shop.head(-1)
# Out:
#                 name relation           shop   rent
# tailor_1  jiyaul Hak    uncle  prince tailor  10000
# tailor_2       sanam     bhai  prince tailor  10000

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
idx=["tailor_1","tailor_2","tailor_3"]
shop=pd.DataFrame(my_shop,index=idx)
shop.head(-4)
# Out:
# Empty DataFrame
# Columns: [name, relation, shop, rent]
# Index: []

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
idx=["tailor_1","tailor_2","tailor_3"]
shop=pd.DataFrame(my_shop,index=idx)
shop.tail(-1)
# Out:
#              name relation           shop   rent
# tailor_2    sanam     bhai  prince tailor  10000
# tailor_3  subrati     bhai  prince tailor  10000

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
idx=["tailor_1","tailor_2","tailor_3"]
shop=pd.DataFrame(my_shop,index=idx)
shop.tail(-2)
# Out:
#              name relation           shop   rent
# tailor_3  subrati     bhai  prince tailor  10000

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
idx=["tailor_1","tailor_2","tailor_3"]
shop=pd.DataFrame(my_shop,index=idx)
shop.describe()
# Out:
#           rent
# count      3.0
# mean   10000.0
# std        0.0
# min    10000.0
# 25%    10000.0
# 50%    10000.0
# 75%    10000.0
# max    10000.0

# %%
import pandas as pd
my_shop={
    "name":["jiyaul Hak","sanam","subrati"],
    "relation":["uncle","bhai","bhai"],
    "shop":"prince tailor",
    "rent":10000
}
idx=["tailor_1","tailor_2","tailor_3"]
shop=pd.DataFrame(my_shop,index=idx)
shop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, tailor_1 to tailor_3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      3 non-null      object
#  1   relation  3 non-null      object
#  2   shop      3 non-null      object
#  3   rent      3 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 120.0+ bytes

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purachse":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company,index=idx)
company_data
# Out:
#            Bat                Signed    Game  Purachse   Runs
# Bat_1      MRF           Virat_Kohli     ipl     20000      6
# Bat_2     CEAT          Rohit_Sharma     icc     15000  4_run
# Bat_3  REBOOKE  Mahendra_singh_Dhoni  series     10000  2_run
# Bat_4       SS     Surya_kumar_Yadav  county     12000  1_run

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purachse":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company,index=idx)
company_data.describe()
# Out:
#           Purachse
# count      4.00000
# mean   14250.00000
# std     4349.32945
# min    10000.00000
# 25%    11500.00000
# 50%    13500.00000
# 75%    16250.00000
# max    20000.00000

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purachse":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company,index=idx)
company_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Bat_1 to Bat_4
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Bat       4 non-null      object
#  1   Signed    4 non-null      object
#  2   Game      4 non-null      object
#  3   Purachse  4 non-null      int64
#  4   Runs      4 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 192.0+ bytes

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purachse":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company,index=idx)
company_data.head(2).tail(1)
# Out:
#         Bat        Signed Game  Purachse   Runs
# Bat_2  CEAT  Rohit_Sharma  icc     15000  4_run

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company,index=idx)
company_data.tail(3).head(4)
# Out:
#            Bat                Signed    Game  Purchase   Runs
# Bat_2     CEAT          Rohit_Sharma     icc     15000  4_run
# Bat_3  REBOOKE  Mahendra_singh_Dhoni  series     10000  2_run
# Bat_4       SS     Surya_kumar_Yadav  county     12000  1_run

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
#idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.Series(bat_company)
company_data
# Out:
# Bat                                  [MRF, CEAT, REBOOKE, SS]
# Signed      [Virat_Kohli, Rohit_Sharma, Mahendra_singh_Dho...
# Game                               [ipl, icc, series, county]
# Purchase                         [20000, 15000, 10000, 12000]
# Runs                                 [6, 4_run, 2_run, 1_run]
# dtype: object

# %% [markdown]
# # shape attribute--->(rows,columns)--->DataFrame()
# # ------>(rows)--->Series()

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company,index=idx)
company_data.shape
#company_data
# Out:
# (4, 5)

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
#idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.Series(bat_company)
company_data.shape
#company_data
# Out:
# (5,)

# %% [markdown]
# # index  attribute----->(column name as index)---->Series()
# # --------------->(start=0,stop=4,step=1)--------->DataFrame()

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
#idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.Series(bat_company)
company_data.index
# Out:
# Index(['Bat', 'Signed', 'Game', 'Purchase', 'Runs'], dtype='object')

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
#idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company)
company_data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# # Columns attribute------->(column name)---->DataFrame()
# # -------no attribute like columns---Series() because of 1D

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
#idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.DataFrame(bat_company)
company_data.columns
# Out:
# Index(['Bat', 'Signed', 'Game', 'Purchase', 'Runs'], dtype='object')

# %%
bat_company={
    "Bat":["MRF","CEAT","REBOOKE","SS"],
    "Signed":["Virat_Kohli","Rohit_Sharma","Mahendra_singh_Dhoni","Surya_kumar_Yadav"],
    "Game":["ipl","icc","series","county"],
    "Purchase":[20000,15000,10000,12000],
    "Runs":[6,"4_run","2_run","1_run"]
}
#idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
company_data=pd.Series(bat_company)
company_data.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12504\2860105545.py in ?()
#       6     "Runs":[6,"4_run","2_run","1_run"]
#       7 }
#       8 #idx=["Bat_1","Bat_2","Bat_3","Bat_4"]
#       9 company_data=pd.Series(bat_company)
# ---> 10 company_data.columns
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'columns'

# %% [markdown]
# ## .loc[row_name,column_name]
# ## .iloc[row_index,column_index]

# %%
import pandas as pd

df = {
    'Name': ['Talib', 'Anil', 'Raj'],
    'Age': [22, 24, 26],
    'City': ['Rewa', 'Bhopal', 'Indore']
}
index=["a", "b", "c"]
st=pd.DataFrame(df,index=index)
st
# Out:
#     Name  Age    City
# a  Talib   22    Rewa
# b   Anil   24  Bhopal
# c    Raj   26  Indore

# %%
import pandas as pd

df = {
    'Name': ['Talib', 'Anil', 'Raj'],
    'Age': [22, 24, 26],
    'City': ['Rewa', 'Bhopal', 'Indore']
}
index=["a", "b", "c"]
st=pd.DataFrame(df,index=index)
st.loc["a","City"]
st.loc["b","Name"]
# Out:
# 'Anil'

# %%
import pandas as pd

df = {
    'Name': ['Talib', 'Anil', 'Raj'],
    'Age': [22, 24, 26],
    'City': ['Rewa', 'Bhopal', 'Indore']
}
index=["a", "b", "c"]
st=pd.DataFrame(df,index=index)
print(st.iloc[0,1])
# Out:
# 22

# %%
import pandas as pd

df = {
    'Name': ['Talib', 'Anil', 'Raj'],
    'Age': [22, 24, 26],
    'City': ['Rewa', 'Bhopal', 'Indore']
}
index=["a", "b", "c"]
st=pd.DataFrame(df,index=index)
st["Name"]
# Out:
# a    Talib
# b     Anil
# c      Raj
# Name: Name, dtype: object

# %%
import pandas as pd

df = {
    'Name': ['Talib', 'Anil', 'Raj'],
    'Age': [22, 24, 26],
    'City': ['Rewa', 'Bhopal', 'Indore']
}
df["Capacity"]=[20000,300000,1200000]
df
index=["a", "b", "c"]
st=pd.DataFrame(df,index=index)
st[["Name","Age"]]
# Out:
#     Name  Age
# a  Talib   22
# b   Anil   24
# c    Raj   26

# %%
st[st["Age"]>24]
# Out:
#   Name  Age    City  Capacity
# c  Raj   26  Indore   1200000

# %%
st[st["Name"]=="Talib"]
# Out:
#     Name  Age  City  Capacity
# a  Talib   22  Rewa     20000

# %%
df["Capacity"]=[20000,300000,1200000]
df
# Out:
# {'Name': ['Talib', 'Anil', 'Raj'],
#  'Age': [22, 24, 26],
#  'City': ['Rewa', 'Bhopal', 'Indore'],
#  'Capacity': [20000, 300000, 1200000]}

# %%
st
# Out:
#     Name  Age    City  Capacity
# a  Talib   22    Rewa     20000
# b   Anil   24  Bhopal    300000
# c    Raj   26  Indore   1200000

# %% [markdown]
# # series

# %%
import pandas as pd
Purchase=[20000,15000,10000,12000]
data=pd.Series(Purchase)
data
# Out:
# 0    20000
# 1    15000
# 2    10000
# 3    12000
# dtype: int64

# %%
import pandas as pd
Purchase=[20000,15000,10000,12000]
idx=["p1","p2","p3","p4"]
data=pd.Series(Purchase,index=idx)
data
# Out:
# p1    20000
# p2    15000
# p3    10000
# p4    12000
# dtype: int64

# %%
import pandas as pd
Purchase=[20000,15000,10000,12000]
idx=["p1","p2","p3","p4"]
data=pd.Series(Purchase,index=idx)
data.head(2)
# Out:
# p1    20000
# p2    15000
# dtype: int64

# %%
import pandas as pd
Purchase=[20000,15000,10000,12000]
idx=["p1","p2","p3","p4"]
data=pd.Series(Purchase,index=idx)
data.tail(3)
# Out:
# p2    15000
# p3    10000
# p4    12000
# dtype: int64

# %%
import pandas as pd
Purchase=[20000,15000,10000,12000]
idx=["p1","p2","p3","p4"]
data=pd.Series(Purchase,index=idx)
print(data.describe())
# Out:
# count        4.00000
# mean     14250.00000
# std       4349.32945
# min      10000.00000
# 25%      11500.00000
# 50%      13500.00000
# 75%      16250.00000
# max      20000.00000
# dtype: float64

# %%
import pandas as pd
Purchase=[20000,15000,10000,12000]
idx=["p1","p2","p3","p4"]
data=pd.Series(Purchase,index=idx)
data.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 4 entries, p1 to p4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      int64
# dtypes: int64(1)
# memory usage: 64.0+ bytes

# %%
import pandas as pd
ball={'bat': 'mrf',
 'signed': 'virat',
 'purachse': 200,
 'ball': 'kukuborra',
 'weight': 200,
 'price': 3000
     }
ball_data=pd.Series(ball)
ball_data
# Out:
# bat               mrf
# signed          virat
# purachse          200
# ball        kukuborra
# weight            200
# price            3000
# dtype: object

# %%
import pandas as pd
ball={'bat': 'mrf',
 'signed': 'virat',
 'purachse': 200,
 'ball': 'kukuborra',
 'weight': 200,
 'price': 3000
     }
idx=["c_det_1","c_det_2","c_det_3","c_det_4"]
ball_data=pd.Series(ball,index=idx)
print(ball_data)
# Out:
# c_det_1    NaN
# c_det_2    NaN
# c_det_3    NaN
# c_det_4    NaN
# dtype: object

# %%
import pandas as pd
ball={'bat': 'mrf',
 'signed': 'virat',
 'purachse': 200,
 'ball': 'kukuborra',
 'weight': 200,
 'price': 3000
     }
idx=["c_det_1","c_det_2","c_det_3","c_det_4"]
ball_data=pd.DataFrame(ball,index=idx)
ball_data
# Out:
#          bat signed  purachse       ball  weight  price
# c_det_1  mrf  virat       200  kukuborra     200   3000
# c_det_2  mrf  virat       200  kukuborra     200   3000
# c_det_3  mrf  virat       200  kukuborra     200   3000
# c_det_4  mrf  virat       200  kukuborra     200   3000

# %%
import pandas as pd
ball={'bat': 'mrf',
 'signed': 'virat',
 'purachse': 200,
 'ball': 'kukuborra',
 'weight': 200,
 'price': 3000
     }
idx=["c_det_1","c_det_2","c_det_3","c_det_4"]
ball_data=pd.DataFrame(ball,index=idx)
ball_data.describe()
# Out:
#        purachse  weight   price
# count       4.0     4.0     4.0
# mean      200.0   200.0  3000.0
# std         0.0     0.0     0.0
# min       200.0   200.0  3000.0
# 25%       200.0   200.0  3000.0
# 50%       200.0   200.0  3000.0
# 75%       200.0   200.0  3000.0
# max       200.0   200.0  3000.0

# %%
import pandas as pd
list_name=["talib","ansari","vipul","singh"]
name=pd.DataFrame(list_name)
name
# Out:
#         0
# 0   talib
# 1  ansari
# 2   vipul
# 3   singh

# %%
import pandas as pd
list_name=["talib","ansari","vipul","singh"]
idx=["name_1","name_2","name_3","name_4"]
name=pd.DataFrame(list_name,index=idx)
name
# Out:
#              0
# name_1   talib
# name_2  ansari
# name_3   vipul
# name_4   singh

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
print(df.head())
# Out:
#     Name  Age     City Country  Marks Passed
# 0   Aman   27   Indore   India     54    Yes
# 1   Aman   18  Lucknow   India     52    Yes
# 2  Priya   33     Rewa   India     88    Yes
# 3   Zaid   21    Patna   India     58    Yes
# 4  Talib   30    Delhi   India     86    Yes

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
df.shape
# Out:
# (100, 6)

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
df
# Out:
#      Name  Age     City Country  Marks Passed
# 0    Aman   27   Indore   India     54    Yes
# 1    Aman   18  Lucknow   India     52    Yes
# 2   Priya   33     Rewa   India     88    Yes
# 3    Zaid   21    Patna   India     58    Yes
# 4   Talib   30    Delhi   India     86    Yes
# ..    ...  ...      ...     ...    ...    ...
# 95  Talib   26   Bhopal   India     65     No
# 96  Sneha   26   Jaipur   India     83    Yes
# 97  Talib   18   Indore   India     97     No
# 98   Anil   18     Rewa   India     85    Yes
# 99  Talib   21    Delhi   India     78    Yes
#
# [100 rows x 6 columns]

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
df.describe()
# Out:
#               Age       Marks
# count  100.000000  100.000000
# mean    25.740000   75.360000
# std      5.392887   14.338984
# min     18.000000   50.000000
# 25%     21.000000   64.000000
# 50%     25.000000   75.000000
# 75%     30.000000   87.000000
# max     35.000000  100.000000

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     100 non-null    object
#  1   Age      100 non-null    int64
#  2   City     100 non-null    object
#  3   Country  100 non-null    object
#  4   Marks    100 non-null    int64
#  5   Passed   100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
print(df.loc[0,"Age"])
# Out:
# 27

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
df["Name"]
# Out:
# 0      Aman
# 1      Aman
# 2     Priya
# 3      Zaid
# 4     Talib
#       ...
# 95    Talib
# 96    Sneha
# 97    Talib
# 98     Anil
# 99    Talib
# Name: Name, Length: 100, dtype: object

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
pd.set_option('display.max_rows', 200)
df
# Out:
#      Name  Age     City Country  Marks Passed
# 0    Aman   27   Indore   India     54    Yes
# 1    Aman   18  Lucknow   India     52    Yes
# 2   Priya   33     Rewa   India     88    Yes
# 3    Zaid   21    Patna   India     58    Yes
# 4   Talib   30    Delhi   India     86    Yes
# 5   Priya   27   Bhopal   India     78     No
# 6   Talib   20    Patna   India     90     No
# 7    Anil   33     Rewa   India     65    Yes
# 8    Zaid   26   Jaipur   India     72    Yes
# 9     Raj   27   Bhopal   India     71    Yes
# 10  Sonal   18     Rewa   India     70     No
# 11    Raj   23   Bhopal   India     80     No
# 12   Anil   23  Lucknow   India     87     No
# 13   Anil   19  Kolkata   India     59     No
# 14    Raj   25     Pune   India     98     No
# 15   Aman   35  Lucknow   India     85    Yes
# 16   Zaid   23     Rewa   India     81     No
# 17  Talib   30   Bhopal   India     79     No
# 18   Ravi   22   Indore   India     82     No
# ...

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
pd.set_option('display.max_rows', 200)
df["Name"]
# Out:
# 0      Aman
# 1      Aman
# 2     Priya
# 3      Zaid
# 4     Talib
# 5     Priya
# 6     Talib
# 7      Anil
# 8      Zaid
# 9       Raj
# 10    Sonal
# 11      Raj
# 12     Anil
# 13     Anil
# 14      Raj
# 15     Aman
# 16     Zaid
# 17    Talib
# 18     Ravi
# 19     Zaid
# 20    Priya
# 21     Aman
# 22     Zaid
# 23    Nisha
# 24     Zaid
# 25      Raj
# 26    Talib
# 27      Raj
# 28     Aman
# 29    Sonal
# 30    Sneha
# 31    Priya
# 32    Nisha
# 33    Priya
# 34      Raj
# 35     Anil
# 36    Sonal
# 37    Sonal
# 38      Raj
# 39     Anil
# 40    Priya
# 41    Sneha
# 42    Sonal
# 43      Raj
# 44      Raj
# 45    Talib
# 46    Priya
# 47     Anil
# 48    Sneha
# 49     Ravi
# 50    Nisha
# 51    Sneha
# 52      Raj
# 53     Zaid
# 54    Talib
# 55    Talib
# 56      Raj
# 57    Talib
# 58     Zaid
# 59    Talib
# 60    Nisha
# 61     Zaid
# 62    Priya
# 63     Anil
# 64     Zaid
# 65     Ravi
# 66    Nisha
# 67    Sneha
# 68    Sneha
# 69    Nisha
# 70      Raj
# ...

# %%
pd.reset_option('display.max_rows')

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\talib\Downloads\pandas_large_practice_data.csv")
print(df.to_string())
# Out:
#      Name  Age     City Country  Marks Passed
# 0    Aman   27   Indore   India     54    Yes
# 1    Aman   18  Lucknow   India     52    Yes
# 2   Priya   33     Rewa   India     88    Yes
# 3    Zaid   21    Patna   India     58    Yes
# 4   Talib   30    Delhi   India     86    Yes
# 5   Priya   27   Bhopal   India     78     No
# 6   Talib   20    Patna   India     90     No
# 7    Anil   33     Rewa   India     65    Yes
# 8    Zaid   26   Jaipur   India     72    Yes
# 9     Raj   27   Bhopal   India     71    Yes
# 10  Sonal   18     Rewa   India     70     No
# 11    Raj   23   Bhopal   India     80     No
# 12   Anil   23  Lucknow   India     87     No
# 13   Anil   19  Kolkata   India     59     No
# 14    Raj   25     Pune   India     98     No
# 15   Aman   35  Lucknow   India     85    Yes
# 16   Zaid   23     Rewa   India     81     No
# 17  Talib   30   Bhopal   India     79     No
# 18   Ravi   22   Indore   India     82     No
# ...

# %%
import pandas as pd
kirana=pd.read_csv(r"C:\Users\talib\Downloads\kirana_shopping_data.csv")
pd.set_option('display.max_rows', 200)
kirana
# Out:
#    Customer     Product  Quantity  Price_per_unit           Store  \
# 0     Talib     Shampoo         7             120  Kirana Express
# 1       Raj       Wheat         5             479    Fresh Market
# 2     Priya       Sugar        10             214      Daily Mart
# 3     Nisha        Soap         9              15  Kirana Express
# 4     Talib        Soap         9             352    Fresh Market
# 5      Ravi         Tea         3              54    Fresh Market
# 6      Anil       Wheat         7             331    Fresh Market
# 7     Priya        Salt         6             121      Daily Mart
# 8       Raj         Oil         6             303  Kirana Express
# 9      Anil        Soap         9             312  Kirana Express
# 10    Talib         Oil         9             364    Fresh Market
# 11     Zaid     Shampoo         5             205      Daily Mart
# 12    Priya       Sugar        10             345  Kirana Express
# ...

# %%
pd.reset_option('display.max_rows')
